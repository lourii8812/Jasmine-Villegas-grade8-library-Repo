# %% [markdown]
# <a href="https://colab.research.google.com/github/lourii8812/Jasmine-Villegas-grade8-library-Repo/blob/main/Jasmine_Villegas_grade8_library_NB.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install firebase-admin

# %%
import json
import requests

url = "https://raw.githubusercontent.com/lourii8812/Jasmine-Villegas-grade8-library-Repo/refs/heads/main/books.json"
response = requests.get(url)
books = response.json()
print(books)
# Out:
# {'books': [{'id': 2001, 'title': 'Introduction to Python', 'author': 'Juan Dela Cruz', 'details': {'copies': 5, 'available': 3}}, {'id': 2002, 'title': 'Data Structures Basics', 'author': 'Maria Santos', 'details': {'copies': 4, 'available': 2}}, {'id': 2003, 'title': 'Web Development Essentials', 'author': 'Carlos Reyes', 'details': {'copies': 6, 'available': 6}}]}

# %%
import json
import requests
url = "https://raw.githubusercontent.com/lourii8812/Jasmine-Villegas-grade8-library-Repo/refs/heads/main/firebase_key.json"
response = requests.get(url)
firebase_key = response.json()
print(firebase_key)
# Out:
# {'type': 'service_account', 'project_id': 'jasmine-villegas-library-2e1db', 'private_key_id': 'c45a4ab01d49b6c28f082af79e04019e5c70cac6', 'private_key': '-----BEGIN PRIVATE KEY-----\\n83OY3GV73U0+whHOPX9JnWk
# ...

# %%
import firebase_admin
from firebase_admin import credentials, db
cred = credentials.Certificate(firebase_key)
# Initialize the app with your database URL
firebase_admin.initialize_app(cred, {
 "databaseURL": "https://jasmine-villegas-library-2e1db-default-rtdb.asia-southeast1.firebasedatabase.app/"
})
print("Firebase connected successfully!")
